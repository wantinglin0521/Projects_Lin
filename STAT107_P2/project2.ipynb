# %% [markdown]
# # Welcome to My Project 2 🍽️
#
# - Name: Vivian Lin
#
# - Course: STAT/CS/IS 107
#
# - Dataset: World's Best Restaurants(https://www.kaggle.com/datasets/thomasfranois/worlds-best-restaurants)
#
# - Dataset Description: This dataset contains the lists of World’s 50 Best Restaurants, from 2002 to 2023 (except 2020). It is an annual list and awards ceremony that celebrates global culinary diversity, showcasing top restaurants and culinary trends through a voting process involving over 1,000 culinary experts from 27 regions.
#
# - Project Description: As a person who loves to travel and enjoy delicious food in those scenic spots, I am super interested in the World's Best Restaurants because I will want to visit as many as them in the future. However, the ranking of the restaurants changes every year, and it is very difficult for us to visit all of them within limited time and money. Hence, I would like to analyze where can we find the most World's Best Restaurant, and what restaurants are worth visiting by reviewing their average ranking, standard deviation, etc. to determine the consistency and quality of their rankings over time.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Project2 - Part I

# %% [markdown]
# ## Section 1: Load the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset.
df = pd.read_csv("WorldsBestRestaurants.csv")

# Test code.
#df

# %% [markdown]
# ## Section 2: Exploratory Data Analysis
#
# Analyze the dataset into several different approaches.
#
# Puzzle 1: I would like to see which 10 restaurants appear the most in the list from 2002 to 2023.
#
# Puzzle 2: I would like to see which 10 countries appear the most in the list from 2002 to 2023.
#
# Puzzle 3: I would like to see which 10 locations appear the most in the list from 2002 to 2023.
#
# Puzzle 4: Based on the top 10 countries appear the most in the list, I would like to see the yearly average ranking change of the restaurant of the first country that appears in the list from 2002 to 2023.

# %% [markdown]
# ### Puzzle 1

# %%
# Group by restaurant to which 10 restaurants appear in the list the most from 2002 to 2023.

most_restaurant = df[["restaurant", "rank"]].groupby("restaurant").agg("count").sort_values(by="rank", ascending=False).reset_index()
most_restaurant.rename(columns={"rank": "number of times appear in the list"}, inplace=True)
most_restaurant.head(10)
# Out:
#            restaurant  number of times appear in the list
# 0            Mugaritz                                  17
# 1         Le Calandre                                  17
# 2        Le Bernardin                                  17
# 3              Arpège                                  17
# 4               Arzak                                  16
# 5          Steirereck                                  14
# 6    Asador Etxebarri                                  14
# 7  The French Laundry                                  13
# 8            Narisawa                                  13
# 9                Noma                                  13

# %% [markdown]
# ### Observation for Puzzle 1
#
# > *"These are the top 10 restaurant that appear the most in the list from 2002 to 2023. "Mugaritz," "Le Calandre," "Le Bernardin," and "Arpège" even appear 17 times which means that they only miss 4 times to be on the list."*

# %% [markdown]
# ### Puzzle 2

# %%
# Group by country to see the top 10 counties that have the most World’s 50 Best Restaurants from 2002 to 2023.
most_country = df[["country", "rank"]].groupby("country").agg("count").sort_values(by="rank", ascending=False).reset_index()
most_country.rename(columns={"rank": "number of times appear in the list"}, inplace=True)
most_country.head(10)
# Out:
#           country  number of times appear in the list
# 0   United States                                 145
# 1          France                                 141
# 2           Spain                                 114
# 3  United Kingdom                                 103
# 4           Italy                                  84
# 5         Germany                                  47
# 6           Japan                                  34
# 7       Australia                                  32
# 8         Denmark                                  29
# 9            Peru                                  29

# %% [markdown]
# ### Observation for Puzzle 2
#
# > *"During this 21 years, United States has the most top 50 restaurants."*

# %%
# Test code.
#df["country"].value_counts()

# %% [markdown]
# ### Puzzle 3

# %%
# Group by location to see the top 10 locations that have the most World’s 50 Best Restaurants from 2002 to 2023.
most_location = df[["location", "rank"]].groupby("location").agg("count").sort_values(by="rank", ascending=False).reset_index()
most_location.rename(columns={"rank": "number of times appear in the list"}, inplace=True)
most_location.head(10)
# Out:
#         location  number of times appear in the list
# 0          Paris                                 103
# 1         London                                  85
# 2       New York                                  80
# 3          Tokyo                                  33
# 4  San Sebastian                                  31
# 5           Lima                                  29
# 6     Copenhagen                                  29
# 7    Mexico City                                  27
# 8         Sydney                                  21
# 9        Chicago                                  20

# %% [markdown]
# ### Observation for Puzzle 3
#
# > *"During these 21 years, Paris is the city that has the most top 50 restaurants. However, Chicago is ranked at 10 which means that we have easy access to these restaurants."*

# %% [markdown]
# ### Puzzle 4.1

# %%
# Analyze the average ranking of the restaurants in the United States appear in the list form 2002 to 2023. 

# Grouping the dataframe.
rank_sum_US = df[df["country"] == "United States"].groupby("year").agg("sum", numeric_only=True).reset_index()
rank_count_US = df[df["country"] == "United States"].groupby("year").agg("count").reset_index()

# Calculate the average ranking.
rank_sum_US["avg"] = rank_sum_US["rank"] / rank_count_US["rank"]
rank_sum_US.rename(columns={"rank": "sum"}, inplace=True)
rank_sum_US[["year", "sum", "avg"]]
# Out:
#     year  sum        avg
# 0   2002  264  24.000000
# 1   2003  124  17.714286
# 2   2004  230  25.555556
# 3   2005  201  20.100000
# 4   2006  169  21.125000
# 5   2007  195  24.375000
# 6   2008  185  23.125000
# 7   2009  161  20.125000
# 8   2010  193  24.125000
# 9   2011  109  18.166667
# 10  2012  195  24.375000
# 11  2013  126  21.000000
# 12  2014  197  28.142857
# 13  2015  188  31.333333
# 14  2016  161  26.833333
# 15  2017  127  21.166667
# 16  2018  147  24.500000
# 17  2019  206  34.333333
# 18  2021  222  37.000000
# 19  2022  127  42.333333
# 20  2023   52  26.000000

# %% [markdown]
# ### Puzzle 4.2

# %%
# Analyze the average ranking of the restaurants in the France appear in the list form 2002 to 2023. 

# Grouping the dataframe.
rank_sum_FR = df[df["country"] == "France"].groupby("year").agg("sum", numeric_only=True).reset_index()
rank_count_FR = df[df["country"] == "France"].groupby("year").agg("count").reset_index()

# Calculate the average ranking.
rank_sum_FR["avg"] = rank_sum_FR["rank"] / rank_count_FR["rank"]
rank_sum_FR.rename(columns={"rank": "sum"}, inplace=True)
rank_sum_FR[["year", "sum", "avg"]]
# Out:
#     year  sum        avg
# 0   2002  142  23.666667
# 1   2003  108  15.428571
# 2   2004  352  27.076923
# 3   2005  256  25.600000
# 4   2006  239  23.900000
# 5   2007  330  27.500000
# 6   2008  226  22.600000
# 7   2009  167  23.857143
# 8   2010  154  25.666667
# 9   2011  190  23.750000
# 10  2012  149  21.285714
# 11  2013  158  26.333333
# 12  2014  132  26.400000
# 13  2015  127  25.400000
# 14  2016   75  25.000000
# 15  2017  141  23.500000
# 16  2018  101  20.200000
# 17  2019   65  13.000000
# 18  2021   88  29.333333
# 19  2022   81  27.000000
# 20  2023  118  29.500000

# %% [markdown]
# ### Observation for Puzzle 4
#
# > *"For the U.S. restaurants, there the ranking got worse from 2019 to 2022, then it recovers in 2023."*

# %% [markdown]
# > *"For the French restaurants, 2003 and 2019 are the two years that they had great average rankings (average ranking is in top 15 in 2003, and top 13 in 2019)."*

# %% [markdown]
# ## Section 3: Exploratory Data Visualization

# %% [markdown]
# ### Puzzle 1 Plot

# %%
# Plot 10 restaurants appear the most in the list from 2002 to 2023.
most_restaurant.nlargest(columns="number of times appear in the list", n=10).plot.bar(x="restaurant", y="number of times appear in the list")
plt.xlabel("Restaurants")
plt.ylabel("Frequency")
plt.title("Frequency of 10 restaurants appear the most")
plt.legend("")

# %% [markdown]
# ### Observation for Puzzle 1 Plot
#
# > *"Mugaritz," "Le Calandre," "Le Bernardin," and "Arpège" are the restaurants that appear the most."*

# %% [markdown]
# ### Puzzle 2 Plot

# %%
# Plot 10 countries that have the most World’s 50 Best Restaurants from 2002 to 2023.
most_country.nlargest(columns="number of times appear in the list", n=10).plot.bar(x="country", y="number of times appear in the list")
plt.xlabel("Countries")
plt.ylabel("Frequency")
plt.title("Frequency of 10 countries that have the most World’s 50 Best Restaurants")
plt.legend("")

# %% [markdown]
# ### Observation for Puzzle 2 Plot
#
# > *"United States has the most top 50 restaurants."*

# %% [markdown]
# ### Puzzle 3 Plot

# %%
# Plot 10 locations that have the most World’s 50 Best Restaurants from 2002 to 2023.
most_location.nlargest(columns="number of times appear in the list", n=10).plot.bar(x="location", y="number of times appear in the list")
plt.xlabel("Locations")
plt.ylabel("Frequency")
plt.title("Frequency of 10 locations that have the most World’s 50 Best Restaurants")
plt.legend("")

# %% [markdown]
# ### Observation for Puzzle 3 Plot
#
# > *"Paris is the city that has the most top 50 restaurants."*

# %% [markdown]
# ### Puzzle 4.1 Plot

# %%
# Plot the average ranking of the restaurants in the United States appear in the list from 2002 to 2023.
rank_sum_US.plot("year", "avg")
plt.xlabel("Year")
plt.ylabel("Average Ranking Score")
plt.title("Average ranking of the restaurants in the United States appear in the list from 2002 to 2023")
plt.legend(["US"])

# %% [markdown]
# ### Observation for Puzzle 4.1 Plot
#
# > *"The plot visualized the increasing trend of the ranking, which means the ranking got worse, from 2019 to 2022, then it recovered in 2023"*

# %% [markdown]
# ### Puzzle 4.2 Plot

# %%
# Plot the average ranking of the restaurants in the U.S. and France appear in the list from 2002 to 2023.
plt.plot(rank_sum_FR["year"], rank_sum_FR["avg"])
plt.plot(rank_sum_US["year"], rank_sum_US["avg"])
plt.xlabel("Year")
plt.ylabel("Average Ranking Score")
plt.title("Average ranking of the restaurants in the U.S. and France appear in the list from 2002 to 2023")
plt.legend(['FR', 'US'])

# %% [markdown]
# ### Observation for Puzzle 4.2 Plot
#
# > *"From the above plot, we can see that US restaruants have better ranking, smaller y-axis value in the plot, in most of the time before 2013; the French restaruant have better ranking in most of the time from 2014 to 2023."*

# %% [markdown]
# ## Section 4: Planning for Part II
#
# ### Overall Observation and Analysis
#
# > *"I found out that there are some interesting trends in the U.S. and France. In particular, they are ranked at the top two countries that have the most top 50 restaraunts in general. Hence,I would like to find out which country, U.S. or France, has better restaruants within its nation."*
#
# ### Ideas for Part II
#
# > *"I will probably do further analysis using hypothesis testing on the average ranking of these two countries. I can then use the result to claim which country has better restaruant within its nation."*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Project2 - Part II

# %% [markdown]
# ## Section 5: Data Science
#
# By observing the result from Puzzle 2 plot, I found out that the U.S. and France are the first and second countries that have the most World’s 50 Best Restaurants from 2002 to 2023.
#
# I would like to know which country has better average ranking. Hence, I plotted out the average ranking of the restaurants in the U.S. and in France to compare the result. However, sometimes U.S. wins, while sometimes France wins. This shows that they are highly comparable and this also intrigues me to find out which country has a better average ranking from 2002 to 2023. As a result, I decide to do a hypothesis testing on the above mention statement.

# %% [markdown]
# ### Defining Our Hypotheses
#
# *$H_0: \mu _{US} >= \mu _{FR}$*
#
# *$H_1: \mu _{US} < \mu _{FR}$*
#
# Where $\mu _{US}$ refers to the average ranking of the US restaurants
# and $\mu _{FR}$ refer to the average ranking of the French restaurants.

# %% [markdown]
# ## Puzzle 5.1: Prepare for the Dataframe

# %%
# Filter out all restaurants which are located in the U.S. in the dataset from 2002 to 2023.
sample_US = df[(df["country"] == "United States")]

# Test code.
#sample_US

# %%
# Filter out all restaurants which are located in France in the dataset from 2002 to 2023.
sample_FR = df[(df["country"] == "France")]

# Test code.
#sample_FR

# %% [markdown]
# ## Puzzle 5.2: Conducting the Hypothesis Test

# %%
# Hypothesis test.
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(sample_US["rank"], sample_FR["rank"], equal_var=True)

print(f"T-Statistic: {round(t_stat, 4)}")
print(f"P-Value: {round(p_value, 4)}")
# Out:
# T-Statistic: 0.3442
# P-Value: 0.731

# %% [markdown]
# ### Observation for Puzzle 5.2
#
# > *"p-value is 0.731 which is higher than 0.05(siginficant level). Therefore, we do not reject the null hypothesis, meaning the U.S. does not have the better restaruants than France."*

# %% [markdown]
# ## Section 6: Different Data Visualization
#
# In order to observate the differences between the average ranking of the U.S. and France, I decided to visualize the box plot of the them.
#
# In the plot, the green triangle shows the mean and the orange line shows the median.

# %%
# Plot the side by side Box plot.
# Prepare data for plotting.
US_rankings = df[df["country"] == "United States"]["rank"]
FR_rankings = df[df["country"] == "France"]["rank"]

plt.boxplot([US_rankings, FR_rankings], labels=["US", "France"], showmeans=True)

# Adding labels and title.
plt.title("Restaurant Rankings by Countries")
plt.ylabel("Ranking")
plt.xlabel("Country")
plt.grid()
# Out:
# /var/folders/sl/nkyrzpxx0dl5krcsxt3c69cc0000gn/T/ipykernel_98512/4054127108.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([US_rankings, FR_rankings], labels=["US", "France"], showmeans=True)

# %% [markdown]
# ### Observation for Section 6
#
# > *"The plot shows that there is no huge difference between the U.S. and French restaurants in terms of ranking."*

# %% [markdown]
# ## Section 7: Overall Summary
#
# > *"In the first part of this project, I started with some puzzles that people might want to know. For instance, 'What are the restaraunts appeared most frequently on the top 50 list', 'What country appeared most frequently on the top 50 list', and 'What location appeared most frequently on the top 50 list'. After looking into the data to understand the answer to these puzzles, I found out that U.S. and France are the two countries that have the most top 50 restaraunts in the nation. This baffled me to take a step further to find out which of the two countries have better restaraunt in its nation referring to the rankings in the data."*
#
# > *"In the second part of the project, I conducted a hypothesis testing on the average ranking of the two countries. As a result, the p-value of the t-test was 0.731, which is way more higher than 0.05(significant level), indicating that there is no difference in terms of the average ranking of the restaraunts between these two coutries. Hence, if one wants to visit either country to have delicious cuisines, both countries will be a good choice."*

# %% [markdown]
# ## Section 8: Updates for Part I
#
# - I added the section headers.
#
#     [TA: (-6 points): Missing section headers]
#
# - I specifically added the Section 4 "Overall Observation and Analysis" part to explain what I didn't summarize in my Project 2 Part I.
#
#     [TA: Section 4 (-4 points): Did not mention an observation with regards to the overall analysis.]
#
# - I made the outputs of the dataframes in my Project 2 Part I more easier to read.
#
# - I added Puzzle 4.2 to further contrast average ranking between the U.S. and French restaurants from 2002 to 2023 and showed the result in Plot 4.2 in my Project 2 Part I.
